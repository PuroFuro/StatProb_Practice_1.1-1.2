# %% [markdown]
# Fico Simhanandi 5027231030

# %% [markdown]
# Practice nomor 1

# %% [markdown]
# Range

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
print(f"Data: {data}")

def calculate_mean(data):
    return sum(data) / len(data)


def calculate_variance(data):

    mean = calculate_mean(data)
    print(f"Rata-rata: {mean}")  
     
    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x )
  
    
    print(f"Total kuadrat selisih: {sum(squared_diff)}")    
    print(f"Jumlah total data: {len(data)}")    
    

    variance = sum(squared_diff) / len(data)
    print(f"Variansi: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def Range(data):

    nilai_tertinggi = max(data)
    print(f"Nilai tertinggi: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Nilai terendah: {nilai_terendah}")

    data_range = max(data) - min(data)
       
    print(f"\nRange: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range

def Std_deviasi(data):

    variance = calculate_variance(data)
    standard_deviation = variance**0.5
    print(f"\nStandard Deviation: {variance}**0.5 = {standard_deviation}")
    
    return standard_deviation
    

quest = input("apa yang ingin dicari?\n(a) Range\n(b) Standar Deviasi\n= ")
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

if quest == 'a':

    dialog = 'Range'
    y = 1.5 
    x1 = 4/70*1
    x2 = 66/70*1  

    plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {Range(data)}')
    plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
    plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')

    rangenumpy = np.max(data) - np.min(data)
    print("(Jika memakai numpy) Range = " + str(rangenumpy))

elif quest == 'b':
    
    dialog = 'Standar Deviasi'
    mean = calculate_mean(data)
    standard_deviation = Std_deviasi(data)

    plt.axvline(x=mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
    plt.axvline(x=mean - standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
    plt.axvline(x=mean + standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')

    stdnumpy = np.std(data)
    print("(Jika memakai numpy) Standar Deviasi = " + str(stdnumpy))

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(str(dialog))
plt.legend()
plt.show()
# Out:
# Data: [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
# Nilai tertinggi: 19
# Nilai terendah: 9
#
# Range: 19 - 9 = 10
# (Jika memakai numpy) Range = 10

# %% [markdown]
# Standar Deviasi

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
print(f"Data: {data}")

def calculate_mean(data):
    return sum(data) / len(data)


def calculate_variance(data):

    mean = calculate_mean(data)
    print(f"Rata-rata: {mean}")  
     
    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x )
  
    
    print(f"Total kuadrat selisih: {sum(squared_diff)}")    
    print(f"Jumlah total data: {len(data)}")    
    

    variance = sum(squared_diff) / len(data)
    print(f"Variansi: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def Range(data):

    nilai_tertinggi = max(data)
    print(f"Nilai tertinggi: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Nilai terendah: {nilai_terendah}")

    data_range = max(data) - min(data)
       
    print(f"\nRange: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range

def Std_deviasi(data):

    variance = calculate_variance(data)
    standard_deviation = variance**0.5
    print(f"\nStandard Deviation: {variance}**0.5 = {standard_deviation}")
    
    return standard_deviation
    

quest = input("apa yang ingin dicari?\n(a) Range\n(b) Standar Deviasi\n= ")
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

if quest == 'a':

    dialog = 'Range'
    y = 1.5 
    x1 = 4/70*1
    x2 = 66/70*1  

    plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {Range(data)}')
    plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
    plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')

    rangenumpy = np.max(data) - np.min(data)
    print("(Jika memakai numpy) Range = " + str(rangenumpy))

elif quest == 'b':
    
    dialog = 'Standar Deviasi'
    mean = calculate_mean(data)
    standard_deviation = Std_deviasi(data)

    plt.axvline(x=mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
    plt.axvline(x=mean - standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
    plt.axvline(x=mean + standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')

    stdnumpy = np.std(data)
    print("(Jika memakai numpy) Standar Deviasi = " + str(stdnumpy))

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(str(dialog))
plt.legend()
plt.show()
# Out:
# Data: [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
# Rata-rata: 13.2
# Total kuadrat selisih: 91.6
# Jumlah total data: 10
# Variansi: 91.6 / 10 = 9.16
#
# Standard Deviation: 9.16**0.5 = 3.026549190084311
# (Jika memakai numpy) Standar Deviasi = 3.026549190084311

# %% [markdown]
# Untuk practice nomor 1, lebih baik menggunakan standar deviasi karena standar deviasi mencantumkan semua data dimana range hanya dari data terbesar dan terkecil

# %% [markdown]
# Practice nomor 2

# %% [markdown]
# Range

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
print(f"Data: {data}")

def calculate_mean(data):
    return sum(data) / len(data)


def calculate_variance(data):

    mean = calculate_mean(data)
    print(f"Rata-rata: {mean}")  
     
    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x )
  
    
    print(f"Total kuadrat selisih: {sum(squared_diff)}")    
    print(f"Jumlah total data: {len(data)}")    
    

    variance = sum(squared_diff) / len(data)
    print(f"Variansi: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def Range(data):

    nilai_tertinggi = max(data)
    print(f"Nilai tertinggi: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Nilai terendah: {nilai_terendah}")

    data_range = max(data) - min(data)
       
    print(f"\nRange: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range

def Std_deviasi(data):

    variance = calculate_variance(data)
    standard_deviation = variance**0.5
    print(f"\nStandard Deviation: {variance}**0.5 = {standard_deviation}")
    
    return standard_deviation
    

quest = input("apa yang ingin dicari?\n(a) Range\n(b) Standar Deviasi\n= ")
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

if quest == 'a':

    dialog = 'Range'
    y = 1.5 
    x1 = 4/70*1
    x2 = 66/70*1  

    plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {Range(data)}')
    plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
    plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')

    rangenumpy = np.max(data) - np.min(data)
    print("(Jika memakai numpy) Range = " + str(rangenumpy))

elif quest == 'b':
    
    dialog = 'Standar Deviasi'
    mean = calculate_mean(data)
    standard_deviation = Std_deviasi(data)

    plt.axvline(x=mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
    plt.axvline(x=mean - standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
    plt.axvline(x=mean + standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')

    stdnumpy = np.std(data)
    print("(Jika memakai numpy) Standar Deviasi = " + str(stdnumpy))

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(str(dialog))
plt.legend()
plt.show()
# Out:
# Data: [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
# Nilai tertinggi: 19
# Nilai terendah: 9
#
# Range: 19 - 9 = 10
# (Jika memakai numpy) Range = 10

# %% [markdown]
# Standar Deviasi

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [180, 185, 175, 190, 170, 195, 165]
print(f"Data: {data}")

def calculate_mean(data):
    return sum(data) / len(data)


def calculate_variance(data):

    mean = calculate_mean(data)
    print(f"Rata-rata: {mean}")  
     
    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x )
  
    
    print(f"Total kuadrat selisih: {sum(squared_diff)}")    
    print(f"Jumlah total data: {len(data)}")    
    

    variance = sum(squared_diff) / len(data)
    print(f"Variansi: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def Range(data):

    nilai_tertinggi = max(data)
    print(f"Nilai tertinggi: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Nilai terendah: {nilai_terendah}")

    data_range = max(data) - min(data)
       
    print(f"\nRange: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range

def Std_deviasi(data):

    variance = calculate_variance(data)
    standard_deviation = variance**0.5
    print(f"\nStandard Deviation: {variance}**0.5 = {standard_deviation}")
    
    return standard_deviation
    

quest = input("apa yang ingin dicari?\n(a) Range\n(b) Standar Deviasi\n= ")
plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='green')

if quest == 'a':

    dialog = 'Range'
    y = 1.5 
    x1 = 4/70*1
    x2 = 66/70*1  

    plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {Range(data)}')
    plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
    plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')

    rangenumpy = np.max(data) - np.min(data)
    print("(Jika memakai numpy) Range = " + str(rangenumpy))

elif quest == 'b':
    
    dialog = 'Standar Deviasi'
    mean = calculate_mean(data)
    standard_deviation = Std_deviasi(data)

    plt.axvline(x=mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
    plt.axvline(x=mean - standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
    plt.axvline(x=mean + standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')

    stdnumpy = np.std(data)
    print("(Jika memakai numpy) Standar Deviasi = " + str(stdnumpy))

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(str(dialog))
plt.legend()
plt.show()
# Out:
# Data: [180, 185, 175, 190, 170, 195, 165]
# Rata-rata: 180.0
# Total kuadrat selisih: 700.0
# Jumlah total data: 7
# Variansi: 700.0 / 7 = 100.0
#
# Standard Deviation: 100.0**0.5 = 10.0
# (Jika memakai numpy) Standar Deviasi = 10.0

# %% [markdown]
# Untuk nomor 2, menggunakan standar deviasi maupun range tidak apa apa karena data tersebar secara rata
